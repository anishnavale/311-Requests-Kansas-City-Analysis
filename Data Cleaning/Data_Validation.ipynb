# %%
# Importing Libraries
import pandas as pd
import numpy as np

# %%
# Reading CSV File
df = pd.read_csv("/Users/anishnavale/Desktop/DAMG7250 - BDAG/311_Cleaned_Data.csv")

# %%
df.head()
# Out:
#    Unnamed: 0     CASE_ID SOURCE            DEPARTMENT  \
# 0           0  2019119972  PHONE                   NHS
# 1           1  2019207923    WEB          Public Works
# 2           2  2021005976  PHONE                   NHS
# 3           3  2020149407  PHONE                   NHS
# 4           4  2020054721    WEB  Parks and Recreation
#
#                                    WORK_GROUP  \
# 0                    NHS-Dangerous Buildings-
# 1  Public Works-Street and Traffic-District 1
# 2                    NHS-Dangerous Buildings-
# 3              NHS-Neighborhood Preservation-
# 4               Parks and Rec-Central Region-
#
#                                       REQUEST_TYPE  \
# 0  Prop/Build/Construct-Dangerous Building-On list
# 1     Streets / Roadways / Alleys-Crack-District 1
# 2  Prop/Build/Construct-Dangerous Building-On list
# 3                              Property Violations
# 4      Parks & Recreation-Park Maintenance-Central
#
# ...

# %%
df.tail()
# Out:
#          Unnamed: 0     CASE_ID SOURCE                     DEPARTMENT  \
# 1563210     1563210  2019175624  PHONE                            NHS
# 1563211     1563211  2019176099  PHONE           Parks and Recreation
# 1563212     1563212  2019176030  PHONE                            NHS
# 1563213     1563213  2019176115  PHONE                   Public Works
# 1563214     1563214  2019172858    WEB  City Planning and Development
#
#                                                WORK_GROUP  \
# 1563210                                  NHS-Solid Waste-
# 1563211                     Parks and Rec-Central Region-
# 1563212                                  NHS-Solid Waste-
# 1563213     Public Works-Capital Projects-Traffic Permits
# 1563214  City Planning and Development-Permit Compliance-
#
#                                               REQUEST_TYPE  \
# 1563210  Trash / Recycling-Trash Collection-Missed by C...
# 1563211        Parks & Recreation-Park Maintenance-Central
# ...

# %%
df.iloc[700000]
# Out:
# Unnamed: 0                                                              700000
# CASE_ID                                                             2011143497
# SOURCE                                                                   PHONE
# DEPARTMENT                                                                 NHS
# WORK_GROUP                                                    NHS-Solid Waste-
# REQUEST_TYPE                                  Trash Missed by Contractor South
# CATEGORY                                                                 Trash
# TYPE                                                                Contractor
# DETAIL                                                                   South
# CREATION_DATE                                                       06/21/2011
# CREATION_TIME                                                         04:59 PM
# CREATION_MONTH                                                            June
# ...

# %%
df[df['CASE_ID']==2019207923].squeeze()
# Out:
# Unnamed: 0                                                                   1
# CASE_ID                                                             2019207923
# SOURCE                                                                     WEB
# DEPARTMENT                                                        Public Works
# WORK_GROUP                          Public Works-Street and Traffic-District 1
# REQUEST_TYPE                      Streets / Roadways / Alleys-Crack-District 1
# CATEGORY                                           Streets / Roadways / Alleys
# TYPE                                                                     Crack
# DETAIL                                                              District 1
# CREATION_DATE                                                       12/22/2019
# CREATION_TIME                                                         07:56 PM
# CREATION_MONTH                                                        December
# ...

# %%
df[df['CASE_ID']==2019176030].squeeze()
# Out:
# Unnamed: 0                                                             1563212
# CASE_ID                                                             2019176030
# SOURCE                                                                   PHONE
# DEPARTMENT                                                                 NHS
# WORK_GROUP                                                    NHS-Solid Waste-
# REQUEST_TYPE                                  Animals / Pets-Dead Animal -Curb
# CATEGORY                                                        Animals / Pets
# TYPE                                                               Dead Animal
# DETAIL                                                                    Curb
# CREATION_DATE                                                       10/04/2019
# CREATION_TIME                                                         04:07 PM
# CREATION_MONTH                                                         October
# ...

# %%
df[df['CASE_ID']==2011143497].squeeze()
# Out:
# Unnamed: 0                                                              700000
# CASE_ID                                                             2011143497
# SOURCE                                                                   PHONE
# DEPARTMENT                                                                 NHS
# WORK_GROUP                                                    NHS-Solid Waste-
# REQUEST_TYPE                                  Trash Missed by Contractor South
# CATEGORY                                                                 Trash
# TYPE                                                                Contractor
# DETAIL                                                                   South
# CREATION_DATE                                                       06/21/2011
# CREATION_TIME                                                         04:59 PM
# CREATION_MONTH                                                            June
# ...

# %%
for col in df:
    if col == 'Unnamed: 0':
        continue
    print(col, ' : ', df[col].nunique())
# Out:
# CASE_ID  :  1563215
# SOURCE  :  22
# DEPARTMENT  :  24
# WORK_GROUP  :  146
# REQUEST_TYPE  :  1236
# CATEGORY  :  84
# TYPE  :  295
# DETAIL  :  574
# CREATION_DATE  :  5229
# CREATION_TIME  :  1440
# CREATION_MONTH  :  12
# CREATION_YEAR  :  16
# STATUS  :  6
# EXCEEDED_EST_TIMEFRAME  :  3
# CLOSED_DATE  :  4996
# CLOSED_MONTH  :  13
# CLOSED_YEAR  :  17
# DAYS_TO_CLOSE  :  2749
# STREET_ADDRESS  :  277729
# ADDRESS_WITH_GEOCODE  :  307249
# ZIP_CODE  :  66
# NEIGHBORHOOD  :  250
# COUNTY  :  5
# COUNCIL_DISTRICT  :  7
# POLICE_DISTRICT  :  7
# PARCEL_ID_NO  :  175953
# LATITUDE  :  157747
# LONGITUDE  :  126281
# CASE_URL  :  1563215
# 30-60-90_Days_Open_Window  :  5
# CREATION_DATETIME  :  1170649

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'CASE_ID', 'SOURCE', 'DEPARTMENT', 'WORK_GROUP',
#        'REQUEST_TYPE', 'CATEGORY', 'TYPE', 'DETAIL', 'CREATION_DATE',
#        'CREATION_TIME', 'CREATION_MONTH', 'CREATION_YEAR', 'STATUS',
#        'EXCEEDED_EST_TIMEFRAME', 'CLOSED_DATE', 'CLOSED_MONTH', 'CLOSED_YEAR',
#        'DAYS_TO_CLOSE', 'STREET_ADDRESS', 'ADDRESS_WITH_GEOCODE', 'ZIP_CODE',
#        'NEIGHBORHOOD', 'COUNTY', 'COUNCIL_DISTRICT', 'POLICE_DISTRICT',
#        'PARCEL_ID_NO', 'LATITUDE', 'LONGITUDE', 'CASE_URL',
#        '30-60-90_Days_Open_Window', 'CREATION_DATETIME'],
#       dtype='object')
